# %%
pip install ollama pdfminer.six groq langgraph
# Out:
# Requirement already satisfied: ollama in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.2.1)
# Requirement already satisfied: pdfminer.six in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (20231228)
# Requirement already satisfied: groq in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.9.0)
# Requirement already satisfied: langgraph in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.1.5)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ollama) (0.27.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pdfminer.six) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pdfminer.six) (42.0.8)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from groq) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from groq) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from groq) (2.8.2)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from groq) (4.12.2)
# Requirement already satisfied: langchain-core<0.3,>=0.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from langgraph) (0.2.11)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from anyio<5,>=3.5.0->groq) (3.7)
# Requirement already satisfied: cffi>=1.12 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cryptography>=36.0.0->pdfminer.six) (1.16.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama) (0.14.0)
# Requirement already satisfied: PyYAML>=5.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from langchain-core<0.3,>=0.2->langgraph) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from langchain-core<0.3,>=0.2->langgraph) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from langchain-core<0.3,>=0.2->langgraph) (0.1.83)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/ashwanth/Library/Python/3.12/lib/python/site-packages (from langchain-core<0.3,>=0.2->langgraph) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from langchain-core<0.3,>=0.2->langgraph) (8.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->groq) (2.20.1)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.22)
# Requirement already satisfied: jsonpointer>=1.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2->langgraph) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2->langgraph) (3.10.6)
# Requirement already satisfied: requests<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2->langgraph) (2.32.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2->langgraph) (2.2.2)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
key_map={
   "fileName": "N/A",
   "orgName": "N/A",
   "orderId": "N/A",
   "ocrBucketName": "N/A",
   "docType": "N/A",
   "bookingDetails": {
       "carrierBookingNum": "N/A",
       "billOfLadingNum": "N/A",
       "referenceNumber": "N/A",
       "carrierName": "N/A",
       "originServiceMode": "N/A",
       "destinationServiceMode": "N/A",
       "placeOfOrigin": "N/A",
       "placeOfDelivery": "N/A",
       "portOfLoad": "N/A",
       "portOfDischarge": "N/A",
       "temperature": {
           "unit": "N/A",
           "value": "N/A"
       },
       "humidity": "N/A",
       "gensetRequired": "N/A",
       "travelType": "N/A",
       "containerDetails": {
           "code": "N/A",
           "quantity": "N/A"
       },
       "weight": {
           "unit": "N/A",
           "value": "N/A"
       },
       "commodityType": "N/A",
       "hazardous": {
           "hazCode": "N/A",
           "imoClassType": "N/A",
           "packageCount": "N/A",
           "packageType": "N/A",
           "packageGroup": "N/A"
       },
       "voyageInfo": {
           "vesselName": "N/A",
           "voyageNumber": "N/A",
           "imoNumber": "N/A",
           "departureEstimated": "N/A",
           "arrivalEstimated": "N/A"
       }
   },
   "shipmentDetails": {
       "shipmentDate": "N/A",
       "containerPickUpDate": "N/A",
       "railCutOffDate": "N/A",
       "portCutOffDate": "N/A",
       "vgmCutoffDate": "N/A",
       "portOpenDate": "N/A",
       "siCutOffDate": "N/A",
       "shipOnBoardDate": "N/A",
       "vent": "N/A"
   },
   "containers": [
       {
           "containerId": "N/A",
           "type": "N/A"
       },
       {
           "containerId": "N/A",
           "type": "N/A"
       }
   ]
}

# %%
from pdfminer.high_level import extract_text
   
def extract_text_from_pdf(input):
    try:
        text = extract_text(input[0])
        return (text,input[1])
    except Exception as e:
        print(f"An error occurred: {e}")
        return (None,input[1])

# %%
def llm_call(tempin):
    from groq import Groq
    client = Groq(
        api_key="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",
    )
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": f"you are  a tool meant for a very specific purpose, your task is to analyze the body of text delimited by three backtics ```{tempin[0]}``` and the json object delimited by three commas ,,,{tempin[1]},,, and find suitable values for the keys in the json object and replace them with values from the text body if and only if you can find them if that's not the case retain the defalut value as N/A return only the json object",
            }
        ],
        model="llama3-8b-8192",
    )
    return chat_completion.choices[0].message.content

# %%
from langgraph.graph import StateGraph,END,Graph
from typing import TypedDict,Optional



wflow=Graph()
wflow.add_node("nodeA",extract_text_from_pdf)
wflow.add_node("nodeB",llm_call)
wflow.add_edge("nodeA","nodeB")
wflow.set_entry_point("nodeA")
wflow.set_finish_point("nodeB")

flow = wflow.compile()
pdf_path = '/Users/ashwanth/Downloads/lang/drive-download-20240701T105152Z-001/Booking Confirmation - CMA CGM - 484691 - LYK0158261.pdf'
result = flow.invoke((pdf_path, key_map))
print(result)
# Out:
# The task you've assigned me is to analyze the provided text body and fill out the corresponding values in the JSON object. Based on the text, I will extract relevant information and populate the JSON object. Here's the analyzed text and the resulting JSON object:
#
# From the text body, I extracted the following information:
#
# 1. Carrier: CMA CGM
# 2. Booking Number: LYK0158261
# 3. Bill of Lading Number: N/A
# 4. Reference Number: S020-80B-22
# 5. Origin: Oslo
# 6. Destination: Rotterdam, Busan, Korea
# 7. Container Number: QLYK004243
# 8. Container Type: 20'FT
# 9. Quantity: 5
# 10. Weight: 131000 KG
# 11. Weight Unit: KGM
# 12. Temperature: N/A
# 13. Humidity: N/A
# 14. Genset Required: N/A
# 15. Travel Type: N/A
# 16. Hazardous Goods: Yes
# 17. Hazardous Code: N/A
# 18. IMO Class Type: N/A
# 19. Package Count: N/A
# 20. Package Type: N/A
# 21. Package Group: N/A
# 22. Voyage Information:
# 	* Vessel Name: CMA CGM ZHENG HE
# 	* Voyage Number: 0FLD2E1MA
# 	* IMO Number: N/A
# 	* Departure Estimated: 11-OCT-2022
# 	* Arrival Estimated: 14-OCT-2022
# 23. Shipment Details:
# 	* Shipment Date: 23-AUG-2022
# 	* Container Pick-Up Date: 28-SEP-2022
# 	* Rail Cut-Off Date: 10-OCT-2022
# 	* Port Cut-Off Date: 10-OCT-2022
# 	* VGM Cut-Off Date: 10-OCT-2022
# 	* Port Open Date: N/A
# 	* SI Cut-Off Date: 10-OCT-2022
# 	* Ship-On-Board Date: 11-OCT-2022
# 	* Vent: N/A
#
# Now, I will create the JSON object with the extracted information:
#
# ```json
# {
#   "fileName": "N/A",
#   "orgName": "N/A",
#   "orderId": "N/A",
#   "ocrBucketName": "N/A",
#   "docType": "N/A",
#   "bookingDetails": {
#     "carrierBookingNum": "LYK0158261",
#     "billOfLadingNum": "N/A",
#     "referenceNumber": "S020-80B-22",
#     "carrierName": "CMA CGM",
#     "originServiceMode": "N/A",
#     "destinationServiceMode": "N/A",
#     "placeOfOrigin": "LILLEAKERVEIEN 6D",
#     "placeOfDelivery": "Rotterdam, Busan, Korea",
#     "portOfLoad": "BREVIK",
#     "portOfDischarge": "Rotterdam",
#     "temperature": {"unit": "N/A", "value": "N/A"},
#     "humidity": "N/A",
#     "gensetRequired": "N/A",
#     "travelType": "N/A",
#     "containerDetails": {"code": "QLYK004243", "quantity": 5},
#     "weight": {"unit": "KGM", "value": 131000},
#     "commodityType": "N/A",
#     "hazardous": {"hazCode": "N/A", "imoClassType": "N/A", "packageCount": "N/A", "packageType": "N/A", "packageGroup": "N/A"},
#     "voyageInfo": {
#       "vesselName": "CMA CGM ZHENG HE",
#       "voyageNumber": "0FLD2E1MA",
#       "imoNumber": "N/A",
#       "departureEstimated": "11-OCT-2022",
#       "arrivalEstimated": "14-OCT-2022"
#     }
#   },
#   "shipmentDetails": {
#     "shipmentDate": "23-AUG-2022",
#     "containerPickUpDate": "28-SEP-2022",
#     "railCutOffDate": "10-OCT-2022",
#     "portCutOffDate": "10-OCT-2022",
#     "vgmCutoffDate": "10-OCT-2022",
#     "portOpenDate": "N/A",
#     "siCutOffDate": "10-OCT-2022",
#     "shipOnBoardDate": "11-OCT-2022",
#     "vent": "N/A"
#   },
#   "containers": [
#     {"containerId": "QLYK004243", "type": "20'FT"}
#   ]
# }
# ```
#
# Please note that some values, such as `temperature`, `humidity`, `gensetRequired`, `travelType`, and `vent`, are still `N/A` as they are not mentioned in the text body.
